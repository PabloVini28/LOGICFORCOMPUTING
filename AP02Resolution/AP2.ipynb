# %%
# !pip install git+https://github.com/daviromero/anita.git -q
# !pip install git+https://github.com/daviromero/nadia.git -q
from anita.anita_pt_gui import anita, anita_theorem
from nadia.nadia_pt_gui import nadia, nadia_theorem
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# **Nota:10**

# %%
# Para evitar problemas com o salvamento de sua demonstração na questão a seguir, 
# adicione sua demonstração na string abaixo
input_proof_q1='''
1.A->B              pre
2.~A|C->D           pre
3.~B                pre
4.{ ~D              hip
5.      { A         hip
6.        B         ->e 5,1
7.        @         ~e 6,3         
        } 
8.      ~A          ~i 5-7
9.      ~A|C        |i 8
10.      D           ->e 9,2
11.     @           ~e 10,4   
  }
12. D               raa 4-11
'''

# %%
#@title Questão 1 (1.25 pontos) Demonstre em Dedução Natural (NADIA)
#@markdown Execute essa célula para gerar o seu exercício.

nadia_theorem(input_theorem='A->B, ~A|C -> D, ~B |- D',input_proof=input_proof_q1)
# Out:
# HTML(value='<h3>Digite a demonstração de A->B, ~A|C -> D, ~B |- D em Dedução Natural:</h3>')
# Textarea(value='\n', layout=Layout(height='300px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
# Para evitar problemas com o salvamento de sua demonstração na questão a seguir, 
# adicione sua demonstração na string abaixo.
input_proof_q2='''
1. ~B->~A            pre
2. B->C              pre
3. { ~(~A|C)          hip
4.       { B         hip
5.         C         ->e 2,4
6.         ~A|C       |i 5
7.         @         ~e 3,6
         }
8.       ~B          ~i 4-7
9.       ~A          ->e 8,1
10.      ~A|C        |i 9
11.       @          ~e 10,3
   }
12. ~A|C              raa 3-11
'''

# %%
#@title Questão 2 (1.25 pontos) Demonstre em Tableau Analítico (ANITA)
#@markdown Execute essa célula para gerar o seu exercício.

anita_theorem(input_theorem='A->B, ~A|C -> D, ~B |- D',input_proof=input_proof_q2)
# Out:
# HTML(value='<h3>Digite a demonstração de A->B, ~A|C -> D, ~B |- D em Tableau Analítico:</h3>')
# Textarea(value='\n', layout=Layout(height='300px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
# Para evitar problemas com o salvamento de sua demonstração na questão a seguir, 
# adicione sua demonstração na string abaixo
input_proof_q3='''
1. ~B->~A            pre
2. B->C              pre
3. { ~(~A|C)          hip
4.       { B         hip
5.         C         ->e 2,4
6.         ~A|C       |i 5
7.         @         ~e 3,6
         }
8.       ~B          ~i 4-7
9.       ~A          ->e 8,1
10.      ~A|C        |i 9
11.       @          ~e 10,3
   }
12. ~A|C              raa 3-11
'''

# %%
#@title Questão 3 (1.25 pontos) Demonstre em Dedução Natural (NADIA)
#@markdown Execute essa célula para gerar o seu exercício.

nadia_theorem(input_theorem='~B->~A, B->C |- ~A|C',input_proof=input_proof_q3)
# Out:
# HTML(value='<h3>Digite a demonstração de ~B->~A, B->C |- ~A|C em Dedução Natural:</h3>')
# Textarea(value='\n', layout=Layout(height='300px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
# Para evitar problemas com o salvamento de sua demonstração na questão a seguir, 
# adicione sua demonstração na string abaixo
input_proof_q4='''
1.T ~B->~A             pre
2. T B->C              pre
3. F ~A|C              conclusao
4. F ~A                3
5. F C                 3
6. T A                 4
7. { F ~B              1
8.   T  B              7
9.       { F B         2
10.        @           8,9
         }
11.      { T C         2
12.         @          11,5
         }
   }
13. { T ~A              1
14.   F  A              13
15.    @                6,14
   }
'''

# %%
#@title Questão 4 (1.25 pontos) Demonstre em Tableau Analítico (ANITA)
#@markdown Execute essa célula para gerar o seu exercício.

anita_theorem(input_theorem='~B->~A, B->C |- ~A|C',input_proof=input_proof_q4)
# Out:
# HTML(value='<h3>Digite a demonstração de ~B->~A, B->C |- ~A|C em Tableau Analítico:</h3>')
# Textarea(value='\n', layout=Layout(height='300px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
# Para evitar problemas com o salvamento de sua demonstração na questão a seguir, 
# adicione sua demonstração na string abaixo
input_proof_q5=1. '''
1. B->A                   pre
2. ~B|D                   pre
3. (A&D)->C               pre
4. { B                    hip
5.   A                    ->e 4,1
6.        { ~B            hip
7.           @            ~e 6,4
8.           C            @e 7
          }
9.        { D             hip
10.         A&D           &i 9,5
11.         C             ->e 10,3
          }
12.   C                   |e 2,6-8,9-11 
   }
13. B->C                   ->i 4-12
'''

# %%
#@title Questão 5 (1.25 pontos) Demonstre em Dedução Natural (NADIA)
#@markdown Execute essa célula para gerar o seu exercício.

nadia_theorem(input_theorem='B->A, ~B|D, (A&D)->C |- B->C',input_proof=input_proof_q5)
# Out:
# HTML(value='<h3>Digite a demonstração de B->A, ~B|D, (A&D)->C |- B->C em Dedução Natural:</h3>')
# Textarea(value='\n', layout=Layout(height='300px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
# Para evitar problemas com o salvamento de sua demonstração na questão a seguir, 
# adicione sua demonstração na string abaixo
input_proof_q6='''
1. T B->A                pre
2. T ~B|D                pre
3. T (A&D)->C            pre
4. F B->C                conclusao
5. T B                   4
6. F C                   4
7. { F B                 1
8.   @                   7,5
   }
9. { T A                 1
10.    { T ~B            2
11.      F  B            10
12.      @               5,11
       }
13.    { T D             2
14.         { F A&D      3
15.              { F A   14
16.                @     15,9
                 }
17.              { F D   14
18.                @     17,13
                 }
            }
19.         { T C        3
20.           @          19,6
            }
       }
   }
'''

# %%
#@title Questão 6 (1.25 pontos) Demonstre em Tableau Analítico (ANITA)
#@markdown Execute essa célula para gerar o seu exercício.

anita_theorem(input_theorem='B->A, ~B|D, (A&D)->C |- B->C', height_layout='500px',input_proof=input_proof_q6)
# Out:
# HTML(value='<h3>Digite a demonstração de B->A, ~B|D, (A&D)->C |- B->C em Tableau Analítico:</h3>')
# Textarea(value='\n', layout=Layout(height='500px', width='90%'), placeholder='Digite sua demonstração:')
# ...
# Output()

# %%
# Para evitar problemas com o salvamento de sua demonstração na questão a seguir, 
# adicione sua demonstração na string abaixo
input_proof_q7='''# Representamos as afirmações através das seguintes fórmulas:
# 1. A->(V|C) para "Se tenho aumento, então viajo ou compro mais comida"
# 2. ~C para "Não comprei mais comida"
# 3. ~P->~V para "Se não compro picanha, então não viajei"
# 4. A->P para "Se tenho aumento, compro picanha"
# Assim, devemos demonstrar que o raciocínio abaixo é válido:
# ...
1. A->(V|C)                pre
2. ~C                      pre
3. ~P->~V                  pre
4. { A                     hip
5.   V|C                   ->e 4,1
6.       { ~P              hip
7.         ~V              ->e 6,3
8.             { V         hip
9.               @         ~e 8,7
               }
10.            { C         hip
11.              @         ~e 10,2
               }
12.            @           |e 5,8-9,10-11
         }      
13.   P                    raa 6-12
   }
14. A->P                    ->i 4-13
'''

# %%
#@title Questão 7 (1.25 pontos) Demonstre em Dedução Natural (NADIA)
#@markdown Execute essa célula para gerar o seu exercício.
input_text_assumptions=['Se tenho aumento, então viajo ou compro mais comida', 'Não comprei mais comida', 'Se não compro picanha, então não viajei']
input_text_conclusion='Se tenho aumento, compro picanha'
nadia(input_text_assumptions=input_text_assumptions,input_text_conclusion=input_text_conclusion,input_proof=input_proof_q7)
# Out:
# <b>Considere as seguintes afirmações:</b>
# 1. Se tenho aumento, então viajo ou compro mais comida
# 1. Não comprei mais comida
# 1. Se não compro picanha, então não viajei
# <b>Considere a afirmação abaixo segue logicamente das afirmações acima:
# 4. Se tenho aumento, compro picanha
# ### Represente as afirmações acima em lógica e digite sua demonstração em Dedução Natural:
# Textarea(value='# Representamos as afirmações através das seguintes fórmulas:\n# 1. ... para "Se tenho aumento…
# ...
# Output()

# %%
# Para evitar problemas com o salvamento de sua demonstração na questão a seguir, 
# adicione sua demonstração na string abaixo
input_proof_q8='''# Representamos as afirmações através das seguintes fórmulas:
# 1. A->(V|C) para "Se tenho aumento, então viajo ou compro mais comida"
# 2. ~C para "Não comprei mais comida"
# 3. ~P->~V para "Se não compro picanha, então não viajei"
# 4. V para "Viajo"
# Assim, devemos demonstrar que o raciocínio abaixo é válido:
# A->(V|C) , ~C , ~P->~V |- V
1. T A->(V|C)          pre
2. T ~C                pre
3. T ~P->~V            pre
4. F V                 conclusao

5. F C                 2
6. { F ~P              3
7.   T  P              6
   }
8. { T ~V              3
9.   F  V              8
10.       { F A        1
          }
11.       { T V|C      1
12.            { T V   11
13.               @    12,9
               }
14.            { T C   11
15.              @     5,14
               }            
          }
   }
'''

# %%
#@title Questão 8 (1.25 pontos) Demonstre em Tableau Analítico (ANITA)
#@markdown Execute essa célula para gerar o seu exercício.
input_text_assumptions=['Se tenho aumento, então viajo ou compro mais comida', 'Não comprei mais comida', 'Se não compro picanha, então não viajei']
input_text_conclusion='Viajo'
anita(input_text_assumptions=input_text_assumptions,input_text_conclusion=input_text_conclusion,input_proof=input_proof_q8 )
# Out:
# <b>Considere as seguintes afirmações:</b>
# 1. Se tenho aumento, então viajo ou compro mais comida
# 1. Não comprei mais comida
# 1. Se não compro picanha, então não viajei
# <b>Considere a afirmação abaixo segue logicamente das afirmações acima:
# 4. Viajo
# ### Represente as afirmações acima em lógica e digite sua demonstração em Tableau Analítico:
# Textarea(value='# Representamos as afirmações através das seguintes fórmulas:\n# 1. ... para "Se tenho aumento…
# ...
# Output()
